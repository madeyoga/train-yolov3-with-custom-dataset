# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Mon Sep  7 04:07:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# 'Getting started.pdf'  'My Drive'  'Proposal Skripsi.gdoc'   Work   yolov3

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 14291 (delta 0), reused 2 (delta 0), pack-reused 14285
# Receiving objects: 100% (14291/14291), 12.87 MiB | 22.75 MiB/s, done.
# Resolving deltas: 100% (9748/9748), done.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_mlbb_result.cfg

# %%
## 2 classes
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_mlbb_result.cfg
# !sed -i 's/height=416/height=128/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_mlbb_result.cfg
# !sed -i 's/max_batches = 500200/max_batches = 16000/' cfg/yolov3_mlbb_result.cfg
# !sed -i 's/steps=400000,450000/steps=12800,14400/' cfg/yolov3_mlbb_result.cfg
# !sed -i '610 s@classes=80@classes=8@' cfg/yolov3_mlbb_result.cfg
# !sed -i '696 s@classes=80@classes=8@' cfg/yolov3_mlbb_result.cfg
# !sed -i '783 s@classes=80@classes=8@' cfg/yolov3_mlbb_result.cfg
# !sed -i '603 s@filters=255@filters=39@' cfg/yolov3_mlbb_result.cfg
# !sed -i '689 s@filters=255@filters=39@' cfg/yolov3_mlbb_result.cfg
# !sed -i '776 s@filters=255@filters=39@' cfg/yolov3_mlbb_result.cfg

## 1 classes
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=1@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=18@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=18@' cfg/yolov3_training.cfg

# %%
# Create folder on google drive so that we can save there the weights
# !mkdir "/mydrive/yolov3"
# Out:
# mkdir: cannot create directory ‘/mydrive/yolov3’: File exists

# %%
# !echo -e "left_data\nright_data\nid\nresult_defeat\nresult_victory\nscore\ntime\nreport_button" > data/obj.names
# !echo -e 'classes= 8\ntrain = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3/mlbb_result' > data/obj.data
# !mkdir data/obj

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /mydrive/yolov3/mlbb_result/MLBB_Result_v3.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3/mlbb_result/MLBB_Result_v3.zip
# replace data/obj/mlr1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/obj/mlr1.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import glob
images_list = glob.glob("data/obj/*[jpg|png|jpeg]")
print(images_list)
# Out:
# ['data/obj/sample17.jpg', 'data/obj/mlr9.png', 'data/obj/sample15.jpg', 'data/obj/mlr10.jpg', 'data/obj/sample4.jpg', 'data/obj/mlr17.jpg', 'data/obj/mlr11.jpg', 'data/obj/mlr15.jpg', 'data/obj/mlr3.jpg', 'data/obj/sample6.jpg', 'data/obj/sample13.jpg', 'data/obj/sample11.jpg', 'data/obj/sample7.jpg', 'data/obj/sample3.jpg', 'data/obj/mlr6.jpg', 'data/obj/mlr8.jpg', 'data/obj/sample8.jpg', 'data/obj/mlr4.jpeg', 'data/obj/sample2.jpg', 'data/obj/sample14.jpg', 'data/obj/mlr16.jpg', 'data/obj/sample10.jpg', 'data/obj/mlr2.jpg', 'data/obj/sample5.jpg', 'data/obj/sample9.png', 'data/obj/sample16.jpg', 'data/obj/mlr1.jpg', 'data/obj/sample12.jpg']

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %% [markdown]
# **6) Start the training**

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_mlbb_result.cfg /mydrive/yolov3/mlbb_result/yolov3_mlbb_result_v2.weights -dont_show

# %%
# !./darknet detector test data/obj.data cfg/yolov3_mlbb_result.cfg /mydrive/yolov3/mlbb_result/yolov3_mlbb_result_v3.weights -thresh 0.25
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !ls
# Out:
# 3rdparty		      DarknetConfig.cmake.in  net_cam_v3.sh
# backup			      darknet_images.py       net_cam_v4.sh
# build			      darknet.py	      obj
# build.ps1		      darknet_video.py	      README.md
# build.sh		      data		      results
# cfg			      image_yolov3.sh	      scripts
# chart.png		      image_yolov4.sh	      src
# chart_yolov3_mlbb_result.png  include		      video_yolov3.sh
# cmake			      json_mjpeg_streams.sh   video_yolov4.sh
# CMakeLists.txt		      LICENSE
# darknet			      Makefile

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor(cv2.imread('predictions.jpg'), cv2.COLOR_BGR2RGB)
plt.figure(figsize=(20,20))
plt.imshow(img)
